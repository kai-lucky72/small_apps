# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random



def make_web_traffic_data():
    hours = np.arange(1, 744)
    web_hits = np.random.randint(1000, 2000, 743)

    gull = web_hits[np.random.choice(hours, size=2, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')


data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv", delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]

if (y > 2599).any() and (y>1200):
    y = np.nan


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = sp.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

plot_web_traffic(x,y,[f1])
# Out:
# [[      nan       nan]
#  [1.000e+00 2.487e+03]
#  [2.000e+00 2.362e+03]
#  [3.000e+00 1.390e+03]
#  [4.000e+00 1.712e+03]
#  [5.000e+00 1.566e+03]
#  [6.000e+00 1.430e+03]
#  [7.000e+00 1.257e+03]
#  [8.000e+00 1.439e+03]
#  [9.000e+00 1.349e+03]]
# Model parameters: [-1.34905175e-02  1.76636841e+03]
# 133047486.28357016
# C:\Users\user\AppData\Local\Temp\ipykernel_10248\2677296064.py:51: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   mx = sp.linspace(0, x[-1], 1000)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random



def make_web_traffic_data():
    hours = np.arange(1, 744)
    web_hits = 100 - np.random.randint(1000, 2000, 743)

    gull = web_hits[np.random.choice(hours, size=2, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')
    
make_web_traffic_data()


data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv", delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]

if (y > 2599).any() and (y>1200):
    y = np.nan


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = sp.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

plot_web_traffic(x,y,[f1])
# Out:
# web_trafficci.tsv saved
# [[       nan        nan]
#  [ 1.000e+00 -1.727e+03]
#  [ 2.000e+00 -9.570e+02]
#  [ 3.000e+00 -1.067e+03]
#  [ 4.000e+00 -1.514e+03]
#  [ 5.000e+00 -1.200e+03]
#  [ 6.000e+00 -1.750e+03]
#  [ 7.000e+00 -1.094e+03]
#  [ 8.000e+00 -1.240e+03]
#  [ 9.000e+00 -1.056e+03]]
# Model parameters: [-1.65436489e-02 -1.40787806e+03]
# 60462650.15526896
# C:\Users\user\AppData\Local\Temp\ipykernel_10248\2779165227.py:53: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   mx = sp.linspace(0, x[-1], 1000)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')


make_web_traffic_data()

data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0, 8000, 1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

plot_web_traffic(x, y, [f1])
# Out:
# web_trafficci.tsv saved
# [[      nan       nan]
#  [0.000e+00 5.829e+03]
#  [1.000e+00 5.616e+03]
#  [2.000e+00 3.961e+03]
#  [3.000e+00 2.420e+03]
#  [4.000e+00 4.836e+03]
#  [5.000e+00 5.365e+03]
#  [6.000e+00 4.327e+03]
#  [7.000e+00 3.553e+03]
#  [8.000e+00 2.363e+03]]
# Model parameters: [3.62524185e-01 3.37514687e+03]
# 1610908713.7914052

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')


make_web_traffic_data()

data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]

if(y.all()>2599 and y.all()<1500):
    y=np.nan

x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0, 7000, 1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

plot_web_traffic(x, y, [f1])
# Out:
# web_trafficci.tsv saved
# [[      nan       nan]
#  [0.000e+00 2.572e+03]
#  [1.000e+00 5.395e+03]
#  [2.000e+00 4.796e+03]
#  [3.000e+00 2.108e+03]
#  [4.000e+00 5.335e+03]
#  [5.000e+00 5.911e+03]
#  [6.000e+00 5.264e+03]
#  [7.000e+00 5.807e+03]
#  [8.000e+00 2.292e+03]]
# Model parameters: [8.86613757e-02 3.47200300e+03]
# 1565232541.8839908

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')


make_web_traffic_data()

data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0, 7000, 1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))
f2p = np.polyfit(x,y,2)



plot_web_traffic(x, y, [f1])
# Out:
# web_trafficci.tsv saved
# [[      nan       nan]
#  [0.000e+00 5.554e+03]
#  [1.000e+00 1.733e+03]
#  [2.000e+00 1.384e+03]
#  [3.000e+00 5.637e+03]
#  [4.000e+00 5.952e+03]
#  [5.000e+00 5.634e+03]
#  [6.000e+00 5.106e+03]
#  [7.000e+00 3.877e+03]
#  [8.000e+00 5.255e+03]]
# Model parameters: [1.89088742e-01 3.36242008e+03]
# 1548697432.543343

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')



data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
print(data[:10])

x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0, 7000, 1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style, color=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))
f2p = np.polyfit(x,y,2)



plot_web_traffic(x, y, [f1])
# Out:
# [[1.000e+00 2.272e+03]
#  [2.000e+00       nan]
#  [3.000e+00 1.386e+03]
#  [4.000e+00 1.365e+03]
#  [5.000e+00 1.488e+03]
#  [6.000e+00 1.337e+03]
#  [7.000e+00 1.883e+03]
#  [8.000e+00 2.283e+03]
#  [9.000e+00 1.335e+03]
#  [1.000e+01 1.025e+03]]
# Model parameters: [  2.59619213 989.02487106]
# 317389767.339778

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')



data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
print(data[:10])


x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(12, 6))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style,linewidth=2, c=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))
f2p = np.polyfit(x,y,2)



plot_web_traffic(x, y, [f1])
# Out:
# [[1.000e+00 2.272e+03]
#  [2.000e+00       nan]
#  [3.000e+00 1.386e+03]
#  [4.000e+00 1.365e+03]
#  [5.000e+00 1.488e+03]
#  [6.000e+00 1.337e+03]
#  [7.000e+00 1.883e+03]
#  [8.000e+00 2.283e+03]
#  [9.000e+00 1.335e+03]
#  [1.000e+01 1.025e+03]]
# Model parameters: [  2.59619213 989.02487106]
# 317389767.339778

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')



data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
#print(data[:10])


x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(14, 7))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0,7000,1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style,linewidth=2, c=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

f2p = np.polyfit(x,y,2)
print(f2p)

f2=np.poly1d(f2p)
print(error(f2, x, y))



plot_web_traffic(x, y, [f1,f2])
# Out:
# Model parameters: [  2.59619213 989.02487106]
# 317389767.339778
# [ 1.05322215e-02 -5.26545650e+00  1.97476082e+03]
# 179983507.8781792

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')



data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
#print(data[:10])


x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
    """
    plot the web traffic (y) over time (x)
    if models is given, it is expected to be a list of fitted models,
    which will be plotted as well (used later in this chapter).
    """
    plt.figure(figsize=(14, 7))  # width and height of the plot in inches
    plt.scatter(x, y, s=10)
    plt.title("Web Traffic over the last month")
    plt.xlabel("Time")
    plt.yticks(np.arange(0,7000,1000))
    plt.ylabel("Hits/hour")
    plt.xticks([w * 7 * 24 for w in range(5)],
               ['week %i' % (w + 1) for w in range(5)])
    if models:
        colors = ['g', 'k', 'b', 'm', 'r']
        linestyles = ['-', '-.', '--', ':', '-']

        mx = np.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            plt.plot(mx, model(mx), linestyle=style,linewidth=2, c=color)
        plt.legend(["d=%i" % m.order for m in models], loc="upper left")
    plt.autoscale(tight=True)
    plt.grid()
    plt.savefig("web_trafficci.png")


def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

f2p = np.polyfit(x,y,2)
print(f2p)


f2=np.poly1d(f2p)
print(error(f2, x, y))

f3p =np.polyfit(x,y,3)
print(f3p)

f3=np.poly1d(f3p)
print(error(f3,x,y))

f10p =np.polyfit(x,y,10)
print(f10p)

f10=np.poly1d(f10p)
print(error(f10,x,y))

f53p=np.polyfit(x,y,53)
print(f53p)

f53=np.poly1d(f53p)
print(error(f53,x,y))

f100p=np.polyfit(x,y,100)
print(f100p)

f100=np.poly1d(f100p)
print(error(f100,x,y))


plot_web_traffic(x, y, [f1,f2,f3,f10,f53,f100])
# Out:
# Model parameters: [  2.59619213 989.02487106]
# 317389767.339778
# [ 1.05322215e-02 -5.26545650e+00  1.97476082e+03]
# 179983507.8781792
# [ 3.04960132e-05 -2.35893797e-02  4.94226019e+00  1.33328797e+03]
# 139350144.03172523
# [-3.73981969e-22  1.36473757e-18 -2.14294407e-15  1.89884971e-12
#  -1.04570108e-09  3.70867731e-07 -8.45604589e-05  1.19167041e-02
#  -9.41618607e-01  3.33703840e+01  1.26421204e+03]
# 121942326.36357701
# [-6.72759183e-140  1.19710158e-136 -4.66178296e-135 -4.66551759e-131
#  -2.54200123e-128  2.26257602e-126  1.39011216e-122  1.16096943e-119
#   4.32156530e-117 -1.50849864e-114 -3.76602032e-111 -3.20493820e-108
#  -1.48603417e-105  6.29954206e-104  8.53560694e-100  9.11000534e-097
#   5.56789708e-094  1.31793700e-091 -1.52878914e-088 -2.41373158e-085
#  -1.84963280e-082 -7.30248729e-080  2.07994669e-077  6.26235839e-074
#   5.60991108e-071  2.52851719e-068 -4.41920217e-066 -1.85478676e-062
#  -1.62965678e-059 -5.76817640e-057  3.54982953e-054  6.50849471e-051
#   3.79822849e-048 -4.37550438e-046 -2.48094822e-042 -1.57859957e-039
#   3.46274086e-037  1.09205565e-033  3.34319227e-031 -4.93745914e-028
#  -2.97738492e-025  2.64737510e-022  1.18873771e-019 -2.02258692e-016
#   1.03625143e-013 -2.90542929e-011  4.79737959e-009 -4.21040813e-007
#   5.98060236e-006  2.59218391e-003 -2.60192227e-001  1.03507297e+001
#  -1.60104062e+002  2.14972779e+003]
# 109452413.42127776
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\user\anaconda3\Lib\site-packages\numpy\lib\polynomial.py:666: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# C:\Users\user\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 0.00000000e+000 -0.00000000e+000  0.00000000e+000  0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000  0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000  0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000 -0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000 -6.72743904e-140
#   1.19703799e-136 -4.65698848e-135 -4.66492304e-131 -2.54251930e-128
#   2.25944611e-126  1.39013950e-122  1.16111978e-119  4.32296954e-117
#  -1.50805326e-114 -3.76693562e-111 -3.20546838e-108 -1.48602072e-105
#   6.29646380e-104  8.53715651e-100  9.11098939e-097  5.56837507e-094
#   1.31784147e-091 -1.52911002e-088 -2.41398374e-085 -1.85000747e-082
#  -7.30053421e-080  2.08140708e-077  6.26340263e-074  5.60975804e-071
#   2.52784441e-068 -4.42187867e-066 -1.85476170e-062 -1.62955636e-059
#  -5.76621430e-057  3.54971487e-054  6.50735962e-051  3.79785000e-048
#  -4.37165354e-046 -2.48045597e-042 -1.57873655e-039  3.45899591e-037
#   1.09217199e-033  3.34490650e-031 -4.93812000e-028 -2.97834948e-025
#   2.64843199e-022  1.18826399e-019 -2.02248287e-016  1.03624873e-013
#  -2.90548069e-011  4.79754048e-009 -4.21066624e-007  5.98311588e-006
#   2.59203365e-003 -2.60186978e-001  1.03506331e+001 -1.60103272e+002
#   2.14972445e+003]
# 109452420.60936345

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import random


def make_web_traffic_data():
    hours = np.arange(0, 743)
    web_hits = np.random.randint(1000, 6001, 743)

    gull = web_hits[np.random.choice(hours, size=50, replace=False)]
    gull = float(np.nan)

    data = np.column_stack((hours, web_hits))

    np.savetxt('web_trafficcc.tsv', data, delimiter='\t', header='hours\tweb_hits', comments='')

    print('web_trafficci.tsv saved')



data = np.genfromtxt(r"C:\Users\user\PycharmProjects\helloworld\pythonProject\studybud\algorithms\web_trafficcc.tsv",
                     delimiter="\t")
#print(data[:10])


x = data[:, 0]
y = data[:, 1]
x = x[~np.isnan(y)]
y = y[~np.isnan(y)]


def plot_web_traffic(x, y, models=None):
     '''
     Plot the web traffic (y) over time (x).
     If models is given, it is expected to be a list of fitted models,
     which will be plotted as well (used later in this chapter).
     '''
     plt.figure(figsize=(12,6)) # width and height of the plot in inches
     plt.scatter(x, y, s=10)
     plt.title("Web traffic over the last month")
     plt.xlabel("Time")
     plt.ylabel("Hits/hour")
     plt.xticks([w*7*24 for w in range(5)],
     ['week %i' %(w+1) for w in range(5)])
     if models:
         colors = ['g', 'k', 'b', 'm', 'r']
         linestyles = ['-', '-.', '--', ':', '-']
         mx = np.linspace(0, x[-1], 1000)
         for model, style, color in zip(models, linestyles, colors):
             plt.plot(mx, model(mx), linestyle=style, linewidth=2, c=color)
             plt.legend(["d=%i" % m.order for m in models], loc="upper left")
     plt.autoscale(tight=True)
     plt.grid()

def error(f, x, y):
    return np.sum((f(x) - y) ** 2)


fp1 = np.polyfit(x, y, 1)
print("Model parameters: %s" % fp1)

f1 = np.poly1d(fp1)
print(error(f1, x, y))

f2p = np.polyfit(x,y,2)
print(f2p)


f2=np.poly1d(f2p)
print(error(f2, x, y))

f3p =np.polyfit(x,y,3)
print(f3p)

f3=np.poly1d(f3p)
print(error(f3,x,y))

f10p =np.polyfit(x,y,10)
print(f10p)

f10=np.poly1d(f10p)
print(error(f10,x,y))

f53p=np.polyfit(x,y,53)
print(f53p)

f53=np.poly1d(f53p)
print(error(f53,x,y))

f100p=np.polyfit(x,y,100)
print(f100p)

f100=np.poly1d(f100p)
print(error(f100,x,y))


plot_web_traffic(x, y, [f1,f2,f3,f10,f53,f100])
# Out:
# Model parameters: [  2.59619213 989.02487106]
# 317389767.339778
# [ 1.05322215e-02 -5.26545650e+00  1.97476082e+03]
# 179983507.8781792
# [ 3.04960132e-05 -2.35893797e-02  4.94226019e+00  1.33328797e+03]
# 139350144.03172523
# [-3.73981969e-22  1.36473757e-18 -2.14294407e-15  1.89884971e-12
#  -1.04570108e-09  3.70867731e-07 -8.45604589e-05  1.19167041e-02
#  -9.41618607e-01  3.33703840e+01  1.26421204e+03]
# 121942326.36357701
# [-6.72759183e-140  1.19710158e-136 -4.66178296e-135 -4.66551759e-131
#  -2.54200123e-128  2.26257602e-126  1.39011216e-122  1.16096943e-119
#   4.32156530e-117 -1.50849864e-114 -3.76602032e-111 -3.20493820e-108
#  -1.48603417e-105  6.29954206e-104  8.53560694e-100  9.11000534e-097
#   5.56789708e-094  1.31793700e-091 -1.52878914e-088 -2.41373158e-085
#  -1.84963280e-082 -7.30248729e-080  2.07994669e-077  6.26235839e-074
#   5.60991108e-071  2.52851719e-068 -4.41920217e-066 -1.85478676e-062
#  -1.62965678e-059 -5.76817640e-057  3.54982953e-054  6.50849471e-051
#   3.79822849e-048 -4.37550438e-046 -2.48094822e-042 -1.57859957e-039
#   3.46274086e-037  1.09205565e-033  3.34319227e-031 -4.93745914e-028
#  -2.97738492e-025  2.64737510e-022  1.18873771e-019 -2.02258692e-016
#   1.03625143e-013 -2.90542929e-011  4.79737959e-009 -4.21040813e-007
#   5.98060236e-006  2.59218391e-003 -2.60192227e-001  1.03507297e+001
#  -1.60104062e+002  2.14972779e+003]
# 109452413.42127776
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 0.00000000e+000 -0.00000000e+000  0.00000000e+000  0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000  0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000  0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#  -0.00000000e+000 -0.00000000e+000 -0.00000000e+000 -0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000 -0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#   0.00000000e+000  0.00000000e+000  0.00000000e+000 -6.72743904e-140
#   1.19703799e-136 -4.65698848e-135 -4.66492304e-131 -2.54251930e-128
#   2.25944611e-126  1.39013950e-122  1.16111978e-119  4.32296954e-117
#  -1.50805326e-114 -3.76693562e-111 -3.20546838e-108 -1.48602072e-105
#   6.29646380e-104  8.53715651e-100  9.11098939e-097  5.56837507e-094
#   1.31784147e-091 -1.52911002e-088 -2.41398374e-085 -1.85000747e-082
#  -7.30053421e-080  2.08140708e-077  6.26340263e-074  5.60975804e-071
#   2.52784441e-068 -4.42187867e-066 -1.85476170e-062 -1.62955636e-059
#  -5.76621430e-057  3.54971487e-054  6.50735962e-051  3.79785000e-048
#  -4.37165354e-046 -2.48045597e-042 -1.57873655e-039  3.45899591e-037
#   1.09217199e-033  3.34490650e-031 -4.93812000e-028 -2.97834948e-025
#   2.64843199e-022  1.18826399e-019 -2.02248287e-016  1.03624873e-013
#  -2.90548069e-011  4.79754048e-009 -4.21066624e-007  5.98311588e-006
#   2.59203365e-003 -2.60186978e-001  1.03506331e+001 -1.60103272e+002
#   2.14972445e+003]
# 109452420.60936345
